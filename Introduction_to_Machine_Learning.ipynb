# %% [markdown]
# # Introducion
# * Machine learning is the science(and art) of programming conputers so they can learn from data.
# * Machine learning is the field of study that gives computers the ability to learn without being explicitly programmed. - Arthur Samuel, 1959
#
# # Types
# 1. Semi supervised learning
#     1. Continuous Target variable
#         1. Regression
#             1. Housing Price Prediction
#     2. Categorical Target Variable
#
# Learn more:
# [More about ML, AI, DL](https://res.cloudinary.com/dyd911kmh/image/upload/v1661963995/AI_274d58487e.png)

# %% [markdown]
# <img src="https://res.cloudinary.com/dyd911kmh/image/upload/v1661963995/AI_274d58487e.png">

# %% [markdown]
# # Linear regression

# %%
import numpy as np
np.random.seed(29)
x = np.random.randn(200) # snd
y = x * 10 + np.random.randn(200) * 2
print(x, y)
# Out:
# [-0.41748213  0.7060321   1.9159847  -2.1417555   0.71905689  0.46707262
#   0.76672253  0.88200945  0.80875066 -0.94716485 -0.12903843 -0.63086044
#  -1.43842284  0.65220495  0.98494561 -1.1444064   0.38683645  0.4265849
#   2.10646128 -0.19786553 -0.2484003   1.71381789 -0.27356624  1.34747596
#   0.34321934 -0.89567509  2.11825131 -0.28609779  0.24322882 -0.61897527
#   1.63784998 -0.05811961 -1.83694028 -0.7785032   0.83320023 -0.04428776
#   0.55439513 -0.4084749  -0.46409435  0.41800894  0.57453712 -1.74668412
#   1.38228917 -1.26331079 -0.25736174 -0.96723108 -1.20666907  2.66861402
#  -2.47113964  0.07261643 -0.40761335 -1.14510085 -2.32342938  0.08442342
#   0.71087449  0.82788128 -1.59302662 -0.5079899   2.55114425 -1.68596461
#  -0.47842946  1.17949062 -0.00697292  0.98764392  0.22076528 -0.06161137
#  -1.03826422 -0.29860915  0.37449239  0.84802006 -1.09539576 -0.41272231
#  -1.22820766  0.92439358  0.23261627 -0.64493688  0.3318164   1.57982212
# ...

# %%
from scipy import stats
res = stats.pearson(x, y)
res
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-4b97bcd56c6f> in <cell line: 2>()
#       1 from scipy import stats
# ----> 2 res = stats.pearson(x, y)
#       3 res
#
# AttributeError: module 'scipy.stats' has no attribute 'pearson'

# %%
import seaborn as sns
sns.scatterplot(x=x, y=x)
# Out:
# <Axes: >

# %% [markdown]
# # scikit-learn is the machine learning library in python

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-0ee1c0bc0a2d> in <cell line: 4>()
#       2 from sklearn.linear_model import LinearRegression
#       3 model = LinearRegression()
# ----> 4 model.fit(x, y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     646         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     647
# --> 648         X, y = self._validate_data(
#     649             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
X = x.reshape(-1, 1) # X or feature must be in 2 dimensions in LinearRegression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, y) # training
# Out:
# LinearRegression()

# %%
m = model.coef_
c = model.intercept_

# %%
m
# Out:
# array([10.09240235])

# %%
c
# Out:
# -0.09927433818300324

# %%
y_pred = model.predict(X) # prediction
y_pred
# Out:
# array([ -4.31267193,   7.02628565,  19.23761417, -21.71473253,
#          7.15773711,   4.61461042,   7.63879794,   8.80231985,
#          8.06296271,  -9.65844307,  -1.40158213,  -6.46617171,
#        -14.61641634,   6.48304039,   9.841193  , -11.64908421,
#          3.80483473,   4.20599206,  21.15998039,  -2.09621288,
#         -2.60623008,  17.19726539,  -2.86021486,  13.4999952 ,
#          3.36463337,  -9.13878771,  21.27897014,  -2.98668838,
#          2.35548874,  -6.34622178,  16.43056662,  -0.68584082,
#        -18.63841468,  -7.95624181,   8.30971761,  -0.54624427,
#          5.49590438,  -4.22176734,  -4.7831012 ,   4.11944012,
#          5.69918543, -17.7275132 ,  13.85134415, -12.84911509,
#         -2.69667259,  -9.8609596 , -12.27746413,  26.83345205,
#        -25.03900989,   0.63359985,  -4.21307224, -11.65609283,
#        -23.54825844,   0.75276076,   7.07515699,   8.25603666,
#        -16.17673989,  -5.22611279,  25.64789991, -17.11470755,
# ...

# %% [markdown]
# # This is not the right way to do Machine Learning
# * Learning the parameters (m and c) of a prediction function and testing it on the same data is a methodological mistake: a model that would just repeat the labels of the samples that it has just seen would have a perfect score but would fail to predict anything useful on yet-unseen data. This situation is called overfitting. To avoid it, it is common practice when performing a (supervised) machine learning experiment to hold out part of the available data as a test set X_test, y_test

# %% [markdown]
# # Assumption of Linear Regression
# There are four assumptions associated with a linear regression model:
# * Linearity: The relationship between X and the mean of Y is linear.
# * Homoscedasticity: The variance of residual is the same for any value of X.
# * Independence: Observations are independent of each other.
# * Normality: For any fixed value of X, Y is normally distributed.

# %%
sns.histplot(x, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(y, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
# residual and error are same

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, y)
# Out:
# [10.09240235] -0.09927433818300324

# %%
m = model.coef_
c = model.intercept_
print(m, c)
# Out:
# [10.09240235] -0.09927433818300324

# %%
residual = y - y_pred
# residual

# %%
sns.histplot(residual, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
stats.skew(residual)
# Out:
# 0.12071092449511145

# %%
sns.scatterplot(x=x, y=residual)
# Out:
# <Axes: >
